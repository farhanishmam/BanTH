# %%
dev = "AIzaSyA4sznwbRazrU46dvDG2NYrg44P0s5sWrk"

# %% [markdown]
# ## Pull All Comments

# %%
videoID="srlFpb6sSNY" #tSYtPNrYAmg&t

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId=videoID,
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

print(response)

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId=videoID, maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'gIg3gH5TSEpfgg0-eWrzDDWenTM', 'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNKMGdHQUVTQlFpSUlCZ0FFZ1VJaHlBWUFCSUZDSWtnR0FBU0JRaW9JQmdBR0FBaURnb01DTDMxZzdRR0VNRDMwTk1E', 'pageInfo': {'totalResults': 100, 'resultsPerPage': 100}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'HUqKV0ntBnJTFN_tj1VGc2RS80M', 'id': 'UgyJ4z_BjubvzG_ukDt4AaABAg', 'snippet': {'channelId': 'UC7EzwShPoM5RDsIzL8B7cgQ', 'videoId': 'srlFpb6sSNY', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'VSQR5l97pSyEK0_d646_sZqyr1k', 'id': 'UgyJ4z_BjubvzG_ukDt4AaABAg', 'snippet': {'channelId': 'UC7EzwShPoM5RDsIzL8B7cgQ', 'videoId': 'srlFpb6sSNY', 'textDisplay': 'Mag....😂😂😂😂Tanisha characterless', 'textOriginal': 'Mag....😂😂😂😂Tanisha characterless', 'authorDisplayName': '@SalenaBegam-s8l', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mA5iYFWQWr-erQfOrpRSPi7uAL1ykOBKRSbPBDp88Z1xyBT7Je5IKp6_AckwgwsDEc-Q=s48-c-k-c0x00ffffff-no-rj', 
# ...

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'SFszTo7M8cu7TIkXx8gPRL8ijcs',
#  'id': 'Ugx5pwmh5GW2b1ciEPl4AaABAg',
#  'snippet': {'channelId': 'UC7EzwShPoM5RDsIzL8B7cgQ',
#   'videoId': 'srlFpb6sSNY',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'm3GHX4sw9NCJPdrvehEsQA7Fcpo',
#    'id': 'Ugx5pwmh5GW2b1ciEPl4AaABAg',
#    'snippet': {'channelId': 'UC7EzwShPoM5RDsIzL8B7cgQ',
#     'videoId': 'srlFpb6sSNY',
#     'textDisplay': 'Asob meyeder khob ues kora jinis khob valo lage loccha meye😅😅',
#     'textOriginal': 'Asob meyeder khob ues kora jinis khob valo lage loccha meye😅😅',
#     'authorDisplayName': '@md.sharifmollah8166',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/QrCFn_U5nDrrQXji-79JN2H6lmiIl8pf2TnKPQzX3YtzSFccjg-hVn1kFR6QHrIQaOYCxAfNBQ=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@md.sharifmollah8166',
#     'authorChannelId': {'value': 'UCzTD1upBxJOQaMKcqfK-q8g'},
#     'canRate': True,
#     'viewerRating': 'none',
# ...

# %%
df.head(10)
# Out:
#                  author            updated_at  like_count  \
# 0      @user-pg6bu2zb6r  2024-08-08T12:26:02Z           0
# 1  @KobitaIsratul-bu3xk  2024-08-08T12:17:50Z           0
# 2      @user-uk5fq7rx3k  2024-08-07T11:16:16Z           0
# 3       @fariasorna2155  2024-08-02T07:08:22Z           0
# 4     @RafatRafat-xr3bi  2024-08-02T03:11:05Z           0
# 5      @user-mn1jp3fe1m  2024-08-01T04:09:31Z           0
# 6        @aburayhan8511  2024-07-29T13:08:11Z           0
# 7          @BritsyAkrar  2024-07-29T09:43:24Z           0
# 8         @MyMother-i6g  2024-07-28T18:28:06Z           0
# 9            @Ali-s6p5n  2024-07-26T02:53:34Z           0
#
#                                                 text  public
# 0                                কটকটির মতোই লেগেছিল    True
# 1  তোর জন্য তো নাজিমের টুনটুনিই যথেষ্ট যেটার জন্য...    True
# 2                  তোদের সংসার বেশি দিন টিকে থাকবেনা    True
# 3  Khali chari dare dhuiya lav nai..chamra ta o l...    True
# ...

# %%
df
# Out:
#                    author            updated_at  like_count  \
# 0        @user-pg6bu2zb6r  2024-08-08T12:26:02Z           0
# 1    @KobitaIsratul-bu3xk  2024-08-08T12:17:50Z           0
# 2        @user-uk5fq7rx3k  2024-08-07T11:16:16Z           0
# 3         @fariasorna2155  2024-08-02T07:08:22Z           0
# 4       @RafatRafat-xr3bi  2024-08-02T03:11:05Z           0
# ..                    ...                   ...         ...
# 385      @rezaulislam9953  2024-06-10T14:08:27Z           2
# 386      @user-mg7zv7zq2k  2024-06-10T14:07:41Z           5
# 387      @user-re9wl4tu5i  2024-06-10T14:02:27Z           2
# 388      @user-re9wl4tu5i  2024-06-10T14:02:12Z           0
# 389      @user-bl5zk6xz4x  2024-06-10T14:01:04Z           0
#
#                                                   text  public
# 0                                  কটকটির মতোই লেগেছিল    True
# 1    তোর জন্য তো নাজিমের টুনটুনিই যথেষ্ট যেটার জন্য...    True
# ...

# %%
df.to_csv("web_scraping.csv", index=False)

# %% [markdown]
# ## Sort by Likes and Get Top 10

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                   author            updated_at  like_count  \
# 379    @tonniakthair8864  2024-06-10T14:13:40Z         176
# 347     @MisRahana-cd3bq  2024-06-10T15:21:20Z         123
# 357      @muksedamin1893  2024-06-10T14:53:33Z          73
# 344   @RaziyaIslam-rc5uo  2024-06-10T15:29:10Z          72
# 285           @SafaNahar  2024-06-11T02:00:00Z          56
# 368  @Obaidul-bhai-dm1yt  2024-06-10T14:35:39Z          35
# 316          @mricon7160  2024-06-10T17:04:57Z          27
# 323     @user-hi1kj1uh4u  2024-06-10T16:27:35Z          26
# 369     @user-oy5sx9wr4s  2024-06-10T14:34:43Z          25
# 192   @mdmilonahamed4579  2024-06-13T17:06:56Z          22
#
#                                                   text  public
# 379  এইডার মুখ দিয়ে শুধু শপিং করার কথা শুনি লুভী এক...    True
# 347  খারাপ মেয়ে একটা অন্যের সংসার ভেঙ্গে নিজে সংসার...    True
# 357  ছোটলোক তো তাই আর কি 😎 অন্যকে দেখায় বিশেষ করে ...    True
# ...

# %% [markdown]
# #Pull all Comments for Multiple Videos

# %%
# !pip install emoji
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 5.9 MB/s eta 0:00:00
# ...

# %%
import re
import emoji

def check_sentence(sentence):
    # Define the pattern for allowed characters
    allowed_pattern = r'^[A-Za-z0-9\s!"#$%&\'()*+,-./:;<=>?@[\]^_`{|}~]+$'

    # Remove emojis from the sentence
    sentence_without_emoji = ''.join(char for char in sentence if char not in emoji.EMOJI_DATA)

    # Check if the remaining characters match the allowed pattern
    if re.match(allowed_pattern, sentence_without_emoji):
        return True
    else:
        return False

# %%
# Test the function
test_sentences = [
    "Hello, world! 123 😊 @#$%",
    "This is a test sentence.",
    "Contains یونیکڈ characters",
    "Emojis only 😀😃😄😁😆",
    "123!@#$%^&*()_+",
    "Mixed content: ABC 123 !@# 😊",
    "তোর ছালামি তোর কাছে থাক।"
]

for sentence in test_sentences:
    result = check_sentence(sentence)
    print(f"'{sentence}': {result}")
# Out:
# 'Hello, world! 123 😊 @#$%': True
# 'This is a test sentence.': True
# 'Contains یونیکڈ characters': False
# 'Emojis only 😀😃😄😁😆': True
# '123!@#$%^&*()_+': True
# 'Mixed content: ABC 123 !@# 😊': True
# 'তোর ছালামি তোর কাছে থাক।': False

# %%
check_sentence("Faltu😡😡😡😡😡")
# Out:
# True

# %%
# !pip install lingua-language-detector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.2/349.2 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 MB 11.0 MB/s eta 0:00:00
# ...

# %%
from lingua import Language, LanguageDetectorBuilder
import pandas as pd
import re


languages = [Language.ENGLISH, Language.BENGALI]
detector = LanguageDetectorBuilder.from_languages(*languages).build()

spaces_pat = re.compile(r'\s+')
non_word_char_pat = re.compile(r'[^a-zA-Z\'\s]')

def get_english_dictionary():
    with open('/content/drive/MyDrive/ban-th Youtube data/dictionary/words.txt', 'r', encoding='utf-8') as fp:
        return set(fp.read().lower().split())

en_dict = get_english_dictionary()

def is_in_en_dictionary(text):
    purged = non_word_char_pat.sub('', str(text)).lower()
    tokens = spaces_pat.split(purged)
    contains = [int(token in en_dict) for token in tokens]
    confidence = sum(contains) / len(contains)
    return confidence > 0.7


def detect_lang(text):
    if len(spaces_pat.split(str(text))) < 3:
        return 'na'
    language = detector.detect_language_of(str(text))
    if language == Language.ENGLISH:
        return 'en' if is_in_en_dictionary(text) else 'bn-roman'
    return 'bn'


def concat_csvs():
    concatenated_df = df_allowed.copy()
    concatenated_df['lang'] = concatenated_df['text'].apply(lambda x: detect_lang(x))
    concatenated_df = concatenated_df[concatenated_df['lang'] == 'bn-roman']
    concatenated_df.drop(columns='lang', inplace=True)
    concatenated_df.drop_duplicates(subset=['text'], inplace=True)
    # concatenated_df.to_csv('dump/tiktok/all_comments.csv', index=False)
    return concatenated_df

# %% [markdown]
# ## 1. Get Comments Function

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)


def getcomments(video):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video,
      maxResults=10000
  )

  comments = []

  # Execute the request.
  response = request.execute()

  # Get the comments from the response.
  for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']

      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])


  while (1 == 1):
    try:
     nextPageToken = response['nextPageToken']
    except KeyError:
     break
    nextPageToken = response['nextPageToken']
    # Create a new request object with the next page token.
    nextRequest = youtube.commentThreads().list(part="snippet", videoId=video, maxResults=10000, pageToken=nextPageToken)
    # Execute the next request.
    response = nextRequest.execute()
    # Get the comments from the next response.
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  df2 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','video_id','public'])
  return df2

# %%
df = getcomments('7uIfSEouU4E')
df
# Out:
#                       author            updated_at  like_count  \
# 0          @youtubeganna5827  2024-08-04T03:06:02Z           0
# 1         @mdjakirhossain265  2024-08-02T16:30:35Z           0
# 2           @user-zh6yr4sg1f  2024-08-02T16:00:12Z           0
# 3                @fahims1603  2024-08-02T10:49:48Z           0
# 4                @SiamPiyash  2024-08-02T03:15:42Z           0
# ...                      ...                   ...         ...
# 4000      @nishatmohamed9591  2024-07-26T16:20:31Z           0
# 4001  @mrmahadihasanrabbi356  2024-07-26T16:19:59Z           6
# 4002          @Channel-jj5ip  2024-07-26T16:19:55Z           5
# 4003        @user-mt9bi7uv1m  2024-07-26T16:19:41Z          23
# 4004             @humaun3494  2024-07-26T16:19:38Z           1
#
#                                                    text     video_id  public
# 0                              ভিপি নূরকে ছেড়ে দেয়া হোক  7uIfSEouU4E    True
# ...

# %%
df_allowed = df[df['text'].apply(check_sentence)]
df_allowed
# Out:
#                       author            updated_at  like_count  \
# 7              @TanBin-je9lw  2024-07-31T20:45:52Z           0
# 18          @hridoyahmad2017  2024-07-29T10:06:34Z           0
# 38            @tanusreeworld  2024-07-28T14:03:03Z           0
# 49         @AhsanulHoque-t7r  2024-07-28T06:56:42Z           0
# 50          @ROHANAHMEDMASUM  2024-07-28T05:55:23Z           0
# ...                      ...                   ...         ...
# 3972          @aktarbina4563  2024-07-26T16:23:45Z           0
# 3984       @MdAshraful-jh5vs  2024-07-26T16:22:26Z           1
# 3987     @SwapanBiswas-yd1cq  2024-07-26T16:22:01Z           2
# 3991         @abulkhokon6450  2024-07-26T16:21:38Z           0
# 4001  @mrmahadihasanrabbi356  2024-07-26T16:19:59Z           6
#
#                                                    text     video_id  public
# 7     Eigula bola oporadh! Wow amara to jani na eiso...  7uIfSEouU4E    True
# ...

# %%
channel_list = ['hwzpl1SfkzA',
'ZJ_hyQ6JhI8',
 '6jLknFkJBNs',
 '7uIfSEouU4E'               ]

# %%
df = pd.DataFrame()
for i in channel_list:
  df2 = getcomments(i)
  df = pd.concat([df, df2])
df
# Out:
#                       author            updated_at  like_count  \
# 0                @shahnaz808  2024-08-27T12:34:28Z           0
# 1                @Raisha-p1i  2024-08-27T11:33:27Z           0
# 2          @HappyChess-db4yi  2024-08-27T07:56:27Z           0
# 3       @MizanurRahman-zn2iy  2024-08-27T07:00:08Z           0
# 4             @BabuBokul-b5u  2024-08-27T06:40:06Z           0
# ...                      ...                   ...         ...
# 4000      @nishatmohamed9591  2024-07-26T16:20:31Z           0
# 4001  @mrmahadihasanrabbi356  2024-07-26T16:19:59Z           6
# 4002          @Channel-jj5ip  2024-07-26T16:19:55Z           5
# 4003        @user-mt9bi7uv1m  2024-07-26T16:19:41Z          23
# 4004             @humaun3494  2024-07-26T16:19:38Z           1
#
#                                                    text     video_id  public
# 0     আজকে যে বিপদ তোমার  ওপর  এসেছে এটা তোমারই  কর্...  hwzpl1SfkzA    True
# ...

# %%
df_allowed = df[df['text'].apply(check_sentence)]
df_allowed
# Out:
#                       author            updated_at  like_count  \
# 1                @Raisha-p1i  2024-08-27T11:33:27Z           0
# 2          @HappyChess-db4yi  2024-08-27T07:56:27Z           0
# 7               @deechou1518  2024-08-27T02:31:59Z           0
# 11        @AbdurMandal-jo3sk  2024-08-26T17:13:31Z           0
# 17         @NurulIslam-tn1gr  2024-08-26T14:19:57Z           0
# ...                      ...                   ...         ...
# 3972          @aktarbina4563  2024-07-26T16:23:45Z           0
# 3984       @MdAshraful-jh5vs  2024-07-26T16:22:26Z           1
# 3987     @SwapanBiswas-yd1cq  2024-07-26T16:22:01Z           2
# 3991         @abulkhokon6450  2024-07-26T16:21:38Z           0
# 4001  @mrmahadihasanrabbi356  2024-07-26T16:19:59Z           6
#
#                                                 text     video_id  public
# 1                                      Uchit shikkha  hwzpl1SfkzA    True
# ...

# %%
concat_df = concat_csvs()
concat_df
# Out:
#                       author            updated_at  like_count  \
# 2          @HappyChess-db4yi  2024-08-27T07:56:27Z           0
# 11        @AbdurMandal-jo3sk  2024-08-26T17:13:31Z           0
# 17         @NurulIslam-tn1gr  2024-08-26T14:19:57Z           0
# 27                @Wasfi2210  2024-08-25T19:00:11Z           0
# 69          @user-zg6xr2sd4l  2024-08-24T18:27:08Z           0
# ...                      ...                   ...         ...
# 3941             @SamiaFanus  2024-07-26T16:28:33Z           0
# 3972          @aktarbina4563  2024-07-26T16:23:45Z           0
# 3987     @SwapanBiswas-yd1cq  2024-07-26T16:22:01Z           2
# 3991         @abulkhokon6450  2024-07-26T16:21:38Z           0
# 4001  @mrmahadihasanrabbi356  2024-07-26T16:19:59Z           6
#
#                                                    text     video_id  public
# 2                     Magire mudu ke diye Cuda U dorkar  hwzpl1SfkzA    True
# ...

# %%
concat_df['video_id'].value_counts()
# Out:
# video_id
# hwzpl1SfkzA    771
# 6jLknFkJBNs    687
# 7uIfSEouU4E    391
# ZJ_hyQ6JhI8     42
# Name: count, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
concat_df.to_excel('/content/drive/MyDrive/ban-th Youtube data/youtube_scraping_dbcnews.xlsx', index=False)

# %%
from googleapiclient.discovery import build

def get_channel_info(video_id, api_key):
    # Create YouTube API client
    youtube = build('youtube', 'v3', developerKey=api_key)

    try:
        # Get video details
        video_response = youtube.videos().list(
            part='snippet',
            id=video_id
        ).execute()

        if not video_response['items']:
            return None

        # Extract channel information
        channel_id = video_response['items'][0]['snippet']['channelId']
        channel_title = video_response['items'][0]['snippet']['channelTitle']

        # Optionally get more channel details
        channel_response = youtube.channels().list(
            part='snippet,statistics',
            id=channel_id
        ).execute()

        if channel_response['items']:
            subscriber_count = channel_response['items'][0]['statistics']['subscriberCount']
            channel_description = channel_response['items'][0]['snippet']['description']

            return {
                'channel_id': channel_id,
                'channel_name': channel_title,
                'subscriber_count': subscriber_count,
                'description': channel_description
            }

    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return None

API_KEY = 'AIzaSyA4sznwbRazrU46dvDG2NYrg44P0s5sWrk'
VIDEO_ID = 'hwzpl1SfkzA'

channel_info = get_channel_info(VIDEO_ID, API_KEY)
if channel_info:
    print(f"Channel Name: {channel_info['channel_name']}")
    print(f"Channel ID: {channel_info['channel_id']}")
    print(f"Subscriber Count: {channel_info['subscriber_count']}")
    print(f"Description: {channel_info['description']}")
# Out:
# Channel Name: DBC NEWS
# Channel ID: UCUvXoiDEKI8VZJrr58g4VAw
# Subscriber Count: 6250000
# Description: DBC NEWS private satellite 24 hours live news channel in Bangladesh owned by Dhaka Bangla Media & Communication Ltd.
#
# ডিবিসি নিউজ হচ্ছে একটি উপগ্রহ ভিত্তিক ২৪ ঘন্টা সরাসরি সম্প্রচার বাংলাদেশী টেলিভিশন সংবাদ চ্যানেল। ২০১৬ সালে চ্যানেলটি আনুষ্ঠানিক যাত্রা শুরু করে।
#
# Social Media Links:
# Website: https://dbcnews.tv
# Facebook: https://www.facebook.com/dbcnews.tv
# YouTube: https://www.youtube.com/c/DBCNEWSTV/
# Twitter: https://twitter.com/dbcnews_tv
# Phone: +88 02 9852431-5, +88 09666777322
# Fax: +88 02 9852380

# %%
from googleapiclient.discovery import build
import pandas as pd
from typing import Dict, Optional

# YouTube category ID to name mapping
CATEGORY_MAPPING = {
    '1': 'Film & Animation',
    '2': 'Autos & Vehicles',
    '10': 'Music',
    '15': 'Pets & Animals',
    '17': 'Sports',
    '19': 'Travel & Events',
    '20': 'Gaming',
    '22': 'People & Blogs',
    '23': 'Comedy',
    '24': 'Entertainment',
    '25': 'News & Politics',
    '26': 'Howto & Style',
    '27': 'Education',
    '28': 'Science & Technology',
    '29': 'Nonprofits & Activism'
}

def get_video_info(video_id: str, api_key: str) -> Optional[Dict]:
    youtube = build('youtube', 'v3', developerKey=api_key)

    try:
        # Get video details including categoryId
        video_response = youtube.videos().list(
            part='snippet,contentDetails,statistics',
            id=video_id
        ).execute()

        if not video_response['items']:
            return None

        video_info = video_response['items'][0]['snippet']
        statistics = video_response['items'][0]['statistics']

        # Get category name from ID
        category_id = video_info['categoryId']
        category_name = CATEGORY_MAPPING.get(category_id, 'Unknown')

        # Get channel details
        channel_id = video_info['channelId']
        channel_response = youtube.channels().list(
            part='snippet,statistics',
            id=channel_id
        ).execute()

        channel_info = channel_response['items'][0]
        channel_description = channel_info['snippet']['description']

        return {
            'video_id': video_id,
            'title': video_info['title'],
            'category_id': category_id,
            'category_name': category_name,
            'channel_id': channel_id,
            'channel_name': video_info['channelTitle'],
            'channel_subscribers': channel_info['statistics'].get('subscriberCount'),
            'channel_description': channel_description,
            'view_count': statistics.get('viewCount'),
            'like_count': statistics.get('likeCount'),
            'comment_count': statistics.get('commentCount'),
            'publish_date': video_info['publishedAt']
        }

    except Exception as e:
        print(f"An error occurred for video {video_id}: {str(e)}")
        return None

def process_multiple_videos(video_ids: list, api_key: str) -> pd.DataFrame:
    results = []
    for video_id in video_ids:
        info = get_video_info(video_id, api_key)
        if info:
            results.append(info)

    return pd.DataFrame(results)


VIDEO_IDS = ['EXAMPLE_VIDEO_ID_1', 'EXAMPLE_VIDEO_ID_2']

API_KEY = 'AIzaSyA4sznwbRazrU46dvDG2NYrg44P0s5sWrk'
VIDEO_ID = 'hwzpl1SfkzA'

# For single video
single_video_info = get_video_info(VIDEO_ID, API_KEY)
print(single_video_info)
if single_video_info:
    print(f"Video Category: {single_video_info['category_name']}")
    print(f"Channel Name: {single_video_info['channel_name']}")

# For multiple videos
# df = process_multiple_videos(VIDEO_IDS, API_KEY)
# print("\nCategory distribution:")
# print(df['category_name'].value_counts())


df

# Optional: Save to CSV
# df.to_csv('video_data.csv', index=False)
# Out:
# {'video_id': 'hwzpl1SfkzA', 'title': 'দীপু মনিকে কিল-ঘুষি | DBC NEWS', 'category_id': '25', 'category_name': 'News & Politics', 'channel_id': 'UCUvXoiDEKI8VZJrr58g4VAw', 'channel_name': 'DBC NEWS', 'channel_subscribers': '6250000', 'channel_description': 'DBC NEWS private satellite 24 hours live news channel in Bangladesh owned by Dhaka Bangla Media & Communication Ltd.\n\nডিবিসি নিউজ হচ্ছে একটি উপগ্রহ ভিত্তিক ২৪ ঘন্টা সরাসরি সম্প্রচার বাংলাদেশী টেলিভিশন সংবাদ চ্যানেল। ২০১৬ সালে চ্যানেলটি আনুষ্ঠানিক যাত্রা শুরু করে।\n\nSocial Media Links:\nWebsite: https://dbcnews.tv\nFacebook: https://www.facebook.com/dbcnews.tv\nYouTube: https://www.youtube.com/c/DBCNEWSTV/\nTwitter: https://twitter.com/dbcnews_tv\nPhone: +88 02 9852431-5, +88 09666777322\nFax: +88 02 9852380\n', 'view_count': '6877319', 'like_count': '77699', 'comment_count': '10623', 'publish_date': '2024-08-20T12:58:35Z'}
# Video Category: News & Politics
# Channel Name: DBC NEWS
#
# Category distribution:
# ...
